# %%
import pandas as pd
import pymysql

# %%
trajectory_connection = pymysql.connect(host='localhost',
                    user='root',
                    password='',
                    db='trajectory',
                    charset='utf8',
                    cursorclass=pymysql.cursors.DictCursor)

# %%
label_connection = pymysql.connect(host='localhost',
                    user='root',
                    password='',
                    db='label',
                    charset='utf8',
                    cursorclass=pymysql.cursors.DictCursor)

# %%
sql = "SELECT * FROM `user000`"
pd.read_sql(sql, trajectory_connection)
# Out:
# /tmp/ipykernel_11714/3223603268.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(sql, trajectory_connection)
#          index   Latitude   Longitude  Altitude      UnixTime        Date  \
# 0            0  39.984702  116.318417     492.0  39744.120185  2008-10-23
# 1            1  39.984683  116.318450     492.0  39744.120255  2008-10-23
# 2            2  39.984686  116.318417     492.0  39744.120313  2008-10-23
# 3            3  39.984688  116.318385     492.0  39744.120370  2008-10-23
# 4            4  39.984655  116.318263     492.0  39744.120428  2008-10-23
# ...        ...        ...         ...       ...           ...         ...
# 173865  173865  40.000403  116.327255     149.0  39999.322859  2009-07-05
# 173866  173866  40.000433  116.327209     150.0  39999.322917  2009-07-05
# ...

# %%
sql = "SELECT * FROM `user010`"
pd.read_sql(sql, label_connection)
# Out:
# /tmp/ipykernel_11714/880657569.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(sql, label_connection)
#      index           Start Time             End Time Transportation Mode
# 0        0  2007/06/26 11:32:29  2007/06/26 11:40:29                 bus
# 1        1  2008/03/28 14:52:54  2008/03/28 15:59:59               train
# 2        2  2008/03/28 16:00:00  2008/03/28 22:02:00               train
# 3        3  2008/03/29 01:27:50  2008/03/29 15:59:59               train
# 4        4  2008/03/29 16:00:00  2008/03/30 15:59:59               train
# ..     ...                  ...                  ...                 ...
# 429    429  2008/12/07 10:30:54  2008/12/07 10:34:14                taxi
# 430    430  2008/12/07 10:59:29  2008/12/07 11:29:48               train
# ...
